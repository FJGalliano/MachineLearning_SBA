# %%
import warnings
warnings.simplefilter('ignore')

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame

fla = pd.read_csv('Florida_2.csv')
fla.head()
# Out:
#                          BorrName                     BorrStreet  \
# 0                    TARCA, INC..            3754 NW 54TH STREET
# 1        Around the Clock Fitness           1242 SW Pine Island.
# 2  Integrated Metering Systems, I  11701 South Belcher Road, Sui
# 3  Loving Enterprises Inc and 2 P          7885 Boca Ciega Drive
# 4  Lawrence J. Roberts & Associat          249 Catalonia Avenue.
#
#            BorrCity BorrState  BorrZip  BorrID LoanStatus  GrossApproval  \
# 0             MIAMI        FL    33142     308     CHGOFF        1900000
# 1        Cape coral        FL    33991    8127        PIF         521800
# 2             Largo        FL    33773    4025        PIF          40800
# 3  SAINT PETERSBURG        FL    33706    7228        PIF         332000
# 4      Coral gables        FL    33134    1508     EXEMPT         225000
#
#    SBAGuarantee  PctOfGuarantee   ...     NaicsCode  \
# 0       1425000            0.75   ...        423120
# ...

# %%
# fla.fillna(0, inplace=True)
# fla.head()

# %%
# X used "LoanStatus", "SBAGuarantee",
X = fla[["NaicsCode",  "PctOfGuarantee","DebtCoverage", "Leverage", "PctOfPrinColl","GrossApproval" ]]
y = fla["SBAGuarantee"]
print(X.shape, y.shape)
# Out:
# (15137, 6) (15137,)

# %%
from sklearn.model_selection import train_test_split

#X = pd.get_dummies(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=80)

X_train.head()
# Out:
#        NaicsCode  PctOfGuarantee  DebtCoverage  Leverage  PctOfPrinColl  \
# 14065     541330            0.50          2.25       4.0           1.00
# 5185      484220            0.50          2.25       4.0           1.00
# 14033     541820            0.50          2.25       4.0           1.00
# 11782     443112            0.50          2.50       2.5           0.35
# 9648      721110            0.85          1.00       4.0           0.30
#
#        GrossApproval
# 14065          25000
# 5185          350000
# 14033         100000
# 11782         500000
# 9648           30000

# %%
fla.corr()
# Out:
#                        BorrZip    BorrID  GrossApproval  SBAGuarantee  \
# BorrZip               1.000000 -0.011141       0.021308      0.020373
# BorrID               -0.011141  1.000000       0.050410      0.053166
# GrossApproval         0.021308  0.050410       1.000000      0.994351
# SBAGuarantee          0.020373  0.053166       0.994351      1.000000
# PctOfGuarantee        0.034226  0.018945       0.303418      0.337999
# InterestRate         -0.066152 -0.081250      -0.342449     -0.340474
# TermMonths            0.058260  0.046447       0.450038      0.437010
# ApprovalFiscalYear    0.027121 -0.086432       0.071109      0.062264
# Days2Funded          -0.025972  0.005445      -0.006113     -0.004355
# Status               -0.024614 -0.330870      -0.077507     -0.074426
# DebtCoverage         -0.023663  0.132147      -0.034960     -0.025736
# Leverage             -0.008490 -0.220925      -0.042568     -0.041799
# ...

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="orange", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="purple", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test.min(), xmax=y_test.max())
plt.title("Projected Charge Off Amount for Performing Loans")
plt.show()

# %%
sum(model.predict(X_test) - y_test)
# Out:
# 60267.757805308356

# %%
predict1= model.predict(X_test)

# %%
plt.scatter(range(0, len(y_test)), model.predict(X_test) - y_test, c="purple", label="Testing Data")
plt.show()

# %%
# plt.line(range(0, len(y_test)), predict1, c="purple", label="Testing Data")
# plt.show()

fig, ax = plt.subplots()

for key, grp in fla.groupby(['GrossApproval']):
    ax = grp.plot(ax=ax, kind='line', x='GrossApproval', y='SBAGuarantee', c=key, label=key)

plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-04ead27da2a8> in <module>()
#       5
#       6 for key, grp in fla.groupby(['GrossApproval']):
# ----> 7     ax = grp.plot(ax=ax, kind='line', x='GrossApproval', y='SBAGuarantee', c=key, label=key)
#       8
#       9 plt.legend(loc='best')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2625                           fontsize=fontsize, colormap=colormap, table=table,
#    2626                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2627                           sort_columns=sort_columns, **kwds)
# ...

# %%
#import statsmodels.api as sm

# %%
# X = fla[["GrossApproval", "SBAGuarantee" ,"PctOfGuarantee", "PctOfPrinColl", "DebtCoverage", "Leverage"]]
# y = fla["SBAGuarantee"]


# results = sm.OLS(y,X.astype(float)).fit()
# #       = sm.OLS(y, X.astype(float)).fit()
# #sm.add_constant(X))
# # data = X.copy()



# print( results.summary())

# plt.scatter(X,y)

# X_plot = np.linspace(0,1,15137)

# plt.plot(X_plot, X_plot*results.params[0] + results.params[1])

# plt.show()
