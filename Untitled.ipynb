# %%
import warnings
warnings.simplefilter('ignore')

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame

ill = pd.read_csv('Illinois.csv')
ill.head()
# Out:
#                          BorrName                 BorrStreet       BorrCity  \
# 0       JONNY B ENTERPRISES, INC.          1421 BERGSTROM RD      WINNEBAGO
# 1               US Cash ATMS Inc.         7722 W 99th Street  HICKORY HILLS
# 2  Westgate Cups LTD and Westgate          743 Westgate Road      Deerfield
# 3  Westgate Cups LTD and Westgate          743 Westgate Road      Deerfield
# 4            SARU FOOD MART, INC.  3328 AVENUE OF THE CITIES         MOLINE
#
#   BorrState  BorrZip BusinessType                BankName       BankStreet  \
# 0        IL    61103  CORPORATION  Wisconsin Bank & Trust  119 Junction Rd
# 1        IL    60457  CORPORATION  Wisconsin Bank & Trust  119 Junction Rd
# 2        IL    60015  CORPORATION  Wisconsin Bank & Trust  119 Junction Rd
# 3        IL    60015  CORPORATION  Wisconsin Bank & Trust  119 Junction Rd
# 4        IL    61265  CORPORATION  Wisconsin Bank & Trust  119 Junction Rd
#
# ...

# %%
# X = ill[["GrossApproval", "SBAGuaranteedApproval", "ApprovalFiscalYear", "InitialInterestRate", "TermInMonths"]]
# y = ill["LoanStatus"].values.reshape(-1, 1)
# print(X.shape, y.shape)
# Out:
# (14793, 5) (14793, 1)

# %%
X = ill[["NaicsDescription", "TermInMonths"]]
y = ill["LoanStatus"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (14793, 2) (14793, 1)

# %%
data = X.copy()

data_binary_encoded = pd.get_dummies(data, columns=["NaicsDescription"])
data_binary_encoded.head()
# Out:
#    TermInMonths  NaicsDescription_Abrasive Product Manufacturing  \
# 0            84                                                0
# 1           120                                                0
# 2           120                                                0
# 3            84                                                0
# 4           300                                                0
#
#    NaicsDescription_Adhesive Manufacturing  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
#
#    NaicsDescription_Administrative Management and General Management Consulting Services  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %%
data = y.copy()

data_binary_encoded = pd.get_dummies(data, columns=["LoanStatus"])
data_binary_encoded.head()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-10-5bfbcd10776c> in <module>()
#       1 data = y.copy()
#       2
# ----> 3 data_binary_encoded = pd.get_dummies(data, columns=["LoanStatus"])
#       4 data_binary_encoded.head()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first)
#    1214     else:
#    1215         result = _get_dummies_1d(data, prefix, prefix_sep, dummy_na,
# -> 1216                                  sparse=sparse, drop_first=drop_first)
#    1217     return result
#    1218
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in _get_dummies_1d(data, prefix, prefix_sep, dummy_na, sparse, drop_first)
#    1221                     sparse=False, drop_first=False):
#    1222     # Series avoids inconsistent NaN handling
# ...

# %%
from sklearn.model_selection import train_test_split

X = pd.get_dummies(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=30)

X_train.head()
# Out:
#        TermInMonths  NaicsDescription_Abrasive Product Manufacturing  \
# 3417             60                                                0
# 3892             84                                                0
# 10470            12                                                0
# 8726             84                                                0
# 5111            120                                                0
#
#        NaicsDescription_Adhesive Manufacturing  \
# 3417                                         0
# 3892                                         0
# 10470                                        0
# 8726                                         0
# 5111                                         0
#
#        NaicsDescription_Administrative Management and General Management Consulting Services  \
# 3417                                                   0
# 3892                                                   0
# ...

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-a8f9234bae94> in <module>()
#       1 from sklearn.preprocessing import StandardScaler
#       2 X_scaler = StandardScaler().fit(X_train)
# ----> 3 y_scaler = StandardScaler().fit(y_train)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py in fit(self, X, y)
#     588         # Reset internal state before fitting
#     589         self._reset()
# --> 590         return self.partial_fit(X, y)
#     591
#     592     def partial_fit(self, X, y=None):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py in partial_fit(self, X, y)
#     610         """
#     611         X = check_array(X, accept_sparse=('csr', 'csc'), copy=self.copy,
# --> 612                         warn_on_dtype=True, estimator=self, dtype=FLOAT_DTYPES)
#     613
# ...
